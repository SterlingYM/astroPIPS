# %% [markdown]
# # Visualization
#
# A set of visualization tools are planned to be implemented in the future versions, but the current version supports some tools for visualization too. Here are some

# %% [markdown]
# ## Drawing periodogram

# %%
import PIPS
import numpy as np
import matplotlib.pyplot as plt
PIPS.about()
# Out:
# --------------------------
# -    Welcome to PIPS!    -
# --------------------------
# Version: 0.3.0-alpha.6
# Authors: Y. Murakami, A. Savel, J. Sunseri, A. Hoffman
# --------------------------
# Download the latest version from: https://pypi.org/project/astroPIPS
# Report issues to: https://github.com/SterlingYM/astroPIPS
# Read the documentations at: https://PIPS.readthedocs.io
# --------------------------

# %%
data = PIPS.data_readin_LPP('../sample_data/005.dat',filter='V')
star = PIPS.photdata(data,label='005')
star.multiprocessing=False

star.periodogram().plot()
star.periodogram(p_max=1.0).plot(show_peak=True)
star.periodogram(p_max=1.0).zoom().plot(show_peak=True)
star.periodogram(p_max=1.0).zoom().refine().plot(show_peak=True)

# %%
star.periodogram(p_max=1).SDE().plot()

# %% [markdown]
# ## Plotting light curve

# %%
star.get_period(multiprocessing=False);

# %%
# default
star.plot_lc()

# %%
# change color
star.plot_lc(color='orange')

# %%
# change figsize, add label, change y-axis label...
star.plot_lc(figsize=(5,2.5),title='New Title',ylabel='New Y-label')

# %%
# add best-fit curve with specific model (model_kwargs is optional for default setting)
star.plot_lc(plot_bestfit=True, model_kwargs={'model':'Fourier','Nterms':7})

# %%
# use existing axes
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,3),sharey=True)
plt.subplots_adjust(wspace=0)
star.plot_lc(ax=ax1)
star.plot_lc(ax=ax2,plot_bestfit=True)

# %%
# if your y-axis is not in mag:
star.plot_lc(invert_yaxis=False,ylabel='flux')

# %%
# if you want to modify the plot a little bit...
ax = star.plot_lc(color='orange',plot_bestfit=True,return_axis=True)
ax.tick_params(direction='in')
ax.set_facecolor('#2f3438')
ax.set_xlim(0,2);
